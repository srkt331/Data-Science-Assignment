# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np

# %%
# !pip install chardet

# %%
import chardet

# %%
with open("ToyotaCorolla.csv", "rb") as f:
    encoding = chardet.detect(f.read())["encoding"]

# %%
#Read the data
tc = pd.read_csv("ToyotaCorolla.csv", encoding=encoding)
tc.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
# 2          9      2002  41711    Diesel  90          1  ...            0
# 3          7      2002  48000    Diesel  90          0  ...            0
# 4          3      2002  38500    Diesel  90          0  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
tc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
#check for missing values
tc.isna().sum()
# Out:
# Id                  0
# Model               0
# Price               0
# Age_08_04           0
# Mfg_Month           0
# Mfg_Year            0
# KM                  0
# Fuel_Type           0
# HP                  0
# Met_Color           0
# Color               0
# Automatic           0
# cc                  0
# Doors               0
# Cylinders           0
# Gears               0
# Quarterly_Tax       0
# Weight              0
# Mfr_Guarantee       0
# BOVAG_Guarantee     0
# Guarantee_Period    0
# ABS                 0
# Airbag_1            0
# Airbag_2            0
# Airco               0
# Automatic_airco     0
# Boardcomputer       0
# CD_Player           0
# Central_Lock        0
# Powered_Windows     0
# Power_Steering      0
# Radio               0
# Mistlamps           0
# Sport_Model         0
# Backseat_Divider    0
# Metallic_Rim        0
# Radio_cassette      0
# Tow_Bar             0
# dtype: int64

# %% [markdown]
# #Correlation

# %%
tc.corr()
# Out:
# <ipython-input-8-7b7daf518aea>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tc.corr()
#                         Id     Price  Age_08_04  Mfg_Month  Mfg_Year  \
# Id                1.000000 -0.738250   0.906132   0.043742 -0.919523
# Price            -0.738250  1.000000  -0.876590  -0.018138  0.885159
# Age_08_04         0.906132 -0.876590   1.000000  -0.123255 -0.983661
# Mfg_Month         0.043742 -0.018138  -0.123255   1.000000 -0.057416
# Mfg_Year         -0.919523  0.885159  -0.983661  -0.057416  1.000000
# KM                0.273298 -0.569960   0.505672  -0.020630 -0.504974
# HP               -0.109375  0.314990  -0.156622  -0.039312  0.164697
# Met_Color        -0.079713  0.108905  -0.108150   0.030266  0.103310
# Automatic         0.066265  0.033081   0.031717   0.009146 -0.033567
# ...

# %% [markdown]
# #Transformation Model

# %%
#Build model
import statsmodels.formula.api as smf
model = smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=tc).fit()

# %%
#Coefficients
model.params
# Out:
# Intercept       -5573.106358
# Age_08_04        -121.658402
# KM                 -0.020817
# HP                 31.680906
# cc                 -0.121100
# Doors              -1.616641
# Gears             594.319936
# Quarterly_Tax       3.949081
# Weight             16.958632
# dtype: float64

# %%
#t and p-Values
print(model.tvalues, '\n', model.pvalues)
# Out:
# Intercept        -3.948666
# Age_08_04       -46.511852
# KM              -16.621622
# HP               11.241018
# cc               -1.344222
# Doors            -0.040410
# Gears             3.016007
# Quarterly_Tax     3.014535
# Weight           15.879803
# dtype: float64
#  Intercept         8.241949e-05
# Age_08_04        3.354724e-288
# KM                7.538439e-57
# HP                3.757218e-28
# cc                1.790902e-01
# Doors             9.677716e-01
# Gears             2.606549e-03
# Quarterly_Tax     2.619148e-03
# Weight            2.048576e-52
# dtype: float64

# %%
#R squared values
(model.rsquared,model.rsquared_adj)
# Out:
# (0.8637627463428191, 0.8629989775766962)

# %%
ml_c=smf.ols('Price~cc',data = tc).fit()
#t and p-Values
print(ml_c.tvalues, '\n', ml_c.pvalues)
# Out:
# Intercept    24.694090
# cc            4.824822
# dtype: float64
#  Intercept    1.766912e-112
# cc            1.550808e-06
# dtype: float64

# %%
ml_d=smf.ols('Price~Doors',data = tc).fit()
print(ml_d.tvalues, '\n', ml_d.pvalues)
# Out:
# Intercept    19.258097
# Doors         7.141657
# dtype: float64
#  Intercept    1.094732e-73
# Doors        1.461237e-12
# dtype: float64

# %%
ml_cd=smf.ols('Price~cc+Doors',data = tc).fit()
print(ml_cd.tvalues, '\n', ml_cd.pvalues)
# Out:
# Intercept    12.620704
# cc            4.340400
# Doors         6.816153
# dtype: float64
#  Intercept    1.056885e-34
# cc           1.521992e-05
# Doors        1.373469e-11
# dtype: float64

# %%
rsq_ag = smf.ols('Age_08_04~KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=tc).fit().rsquared
vif_ag = 1/(1-rsq_ag)

rsq_km = smf.ols('KM~Age_08_04+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=tc).fit().rsquared
vif_km = 1/(1-rsq_km)

rsq_hp = smf.ols('HP~Age_08_04+KM+cc+Doors+Gears+Quarterly_Tax+Weight',data=tc).fit().rsquared
vif_hp = 1/(1-rsq_hp)

rsq_cc = smf.ols('cc~Age_08_04+HP+KM+Doors+Gears+Quarterly_Tax+Weight',data=tc).fit().rsquared
vif_cc = 1/(1-rsq_cc)

rsq_d = smf.ols('Doors~Age_08_04+HP+cc+KM+Gears+Quarterly_Tax+Weight',data=tc).fit().rsquared
vif_d = 1/(1-rsq_d)

rsq_gr = smf.ols('Gears~Age_08_04+HP+cc+Doors+KM+Quarterly_Tax+Weight',data=tc).fit().rsquared
vif_gr = 1/(1-rsq_gr)

rsq_qt = smf.ols('Quarterly_Tax~Age_08_04+HP+cc+Doors+Gears+KM+Weight',data=tc).fit().rsquared
vif_qt = 1/(1-rsq_qt)

rsq_wt = smf.ols('Weight~Age_08_04+HP+cc+Doors+Gears+Quarterly_Tax+KM',data=tc).fit().rsquared
vif_wt = 1/(1-rsq_wt)


# Storing vif values in a data frame
d1 = {'Variables':['Age_08_04', 'HP', 'KM', 'cc', 'Doors', 'Gears', 'Quarterly_Tax', 'Weight'],'VIF':[vif_ag,vif_hp,vif_km,vif_cc,vif_d,vif_gr,vif_qt,vif_wt]}
Vif_frame = pd.DataFrame(d1)
Vif_frame
# Out:
#        Variables       VIF
# 0      Age_08_04  1.884620
# 1             HP  1.419422
# 2             KM  1.756905
# 3             cc  1.163894
# 4          Doors  1.156575
# 5          Gears  1.098723
# 6  Quarterly_Tax  2.311431
# 7         Weight  2.516420

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid>4000))
# Out:
# [array([ 109,  110,  111,  125,  147,  171,  523, 1058])]

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %% [markdown]
# #Cook's Distance

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(tc)), np.round(c, 10))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
#index and value of influencer where c is more than .5
(np.argmax(c),np.max(c))
# Out:
# (80, 79.52010624141815)

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
k = 8
n = tc.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.018802228412256268

# %%
tc[tc.index.isin([80])]
# Out:
#     Id                                Model  Price  Age_08_04  Mfg_Month  \
# 80  81  TOYOTA Corolla 1.6 5drs 1 4/5-Doors  18950         25          8
#
#     Mfg_Year     KM Fuel_Type   HP  Met_Color  ... Central_Lock  \
# 80      2002  20019    Petrol  110          1  ...            1
#
#     Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# 80                1               1      0          0            0
#
#     Backseat_Divider  Metallic_Rim  Radio_cassette  Tow_Bar
# 80                 0             0               0        0
#
# [1 rows x 38 columns]

# %%
#Load the data
tc_new = pd.read_csv("ToyotaCorolla.csv", encoding=encoding)

# %%
#Discard the data points which are influencers and reasign the row number (reset_index())
tc1=tc_new.drop(tc_new.index[[80]],axis=0).reset_index()

# %%
#Drop the original index
tc1=tc1.drop(['index'],axis=1)

# %%
tc1
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1430  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1431  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1432  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1433  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1434  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
#Exclude variable "cc" and generate R-Squared and AIC values
final_ml_c= smf.ols('Price~Age_08_04+KM+HP+cc+Gears+Quarterly_Tax+Weight',data = tc1).fit()

# %%
(final_ml_c.rsquared,final_ml_c.aic,final_ml_c.bic)
# Out:
# (0.8693349475698542, 24685.765438793034, 24727.916799818584)

# %%
#Exclude variable "Doors" and generate R-Squared and AIC values
final_ml_d= smf.ols('Price~Age_08_04+KM+HP+Doors+Gears+Quarterly_Tax+Weight',data = tc1).fit()

# %%
(final_ml_d.rsquared,final_ml_d.aic,final_ml_d.bic)
# Out:
# (0.8631959819380925, 24751.649416173997, 24793.800777199547)

# %%
model_influence_c = final_ml_c.get_influence()
(c_c, _) = model_influence_c.cooks_distance

# %%
fig= plt.subplots(figsize=(20,7))
plt.stem(np.round(c_c,3));
plt.xlabel('Row index')
plt.ylabel('Cooks Distance');

# %%
#index of the data points where c is more than .5
(np.argmax(c_c),np.max(c_c))
# Out:
# (220, 2.3034451664540874)

# %%
#Drop 220
tc2=tc1.drop(tc1.index[[220]],axis=0)
tc2.shape
# Out:
# (1434, 38)

# %%
tc2
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1430  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1431  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1432  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1433  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1434  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
#Reset the index and re arrange the row values
tc3=tc2.reset_index()

# %%
tc4=tc3.drop(['index'],axis=1)

# %%
tc4
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1429  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1430  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1431  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1432  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1433  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
final_ml_c= smf.ols('Price~Age_08_04+KM+HP+cc+Gears+Quarterly_Tax+Weight',data = tc4).fit()

# %%
#Again check for influencers
model_influence_c = final_ml_c.get_influence()
(c_c, _) = model_influence_c.cooks_distance

# %%
fig= plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(tc4)),np.round(c_c,3));
plt.xlabel('Row index')
plt.ylabel('Cooks Distance');

# %%
#index of the data points where c is more than .5
(np.argmax(c_c),np.max(c_c))
# Out:
# (958, 2.2907159163042135)

# %%
tc5=tc4.drop(tc1.index[[958]],axis=0)
tc5
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1429  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1430  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1431  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1432  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1433  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
tc6=tc5.reset_index()
tc6
# Out:
#       index    Id                                              Model  Price  \
# 0         0     1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1         1     2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2         2     3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3         3     4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4         4     5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...     ...   ...                                                ...    ...
# 1428   1429  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1429   1430  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1430   1431  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1431   1432  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1432   1433  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
# ...

# %%
tc7=tc6.drop(['index'],axis=1)
tc7
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1428  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1429  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1430  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1431  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1432  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
#Check the accuracy of the mode
final_ml_c= smf.ols('Price~Age_08_04+KM+HP+cc+Gears+Quarterly_Tax+Weight',data = tc7).fit()

# %%
(final_ml_c.rsquared,final_ml_c.aic)
# Out:
# (0.8843226794628847, 24478.432455892536)

# %%
model_influence_c = final_ml_c.get_influence()
(c_c, _) = model_influence_c.cooks_distance

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
fig= plt.subplots(figsize=(20,7))
plt.stem(np.round(c_c,3));
plt.xlabel('Row index')
plt.ylabel('Cooks Distance');

# %%
(np.argmax(c_c),np.max(c_c))
# Out:
# (599, 0.28772293638955404)

# %%
#New data for prediction
new_data=pd.DataFrame({"Price":13500,"Age_08_04":23,"KM":46986,"HP":90,"cc":2000,"Doors":3,"Gears":5,"Quarterly_Tax":245,"Weight":1200},index=[1])

# %%
final_ml_c.predict(new_data)
# Out:
# 1    17418.49263
# dtype: float64

# %%
final_ml_c.predict(tc_new.iloc[0:5,])
# Out:
# 0    16199.290708
# 1    15752.366936
# 2    16177.734390
# 3    15844.623319
# 4    15705.112271
# dtype: float64

# %%
pred_y = final_ml_c.predict(tc_new)

# %%
pred_y
# Out:
# 0       16199.290708
# 1       15752.366936
# 2       16177.734390
# 3       15844.623319
# 4       15705.112271
#             ...
# 1431     9024.631461
# 1432     8421.042564
# 1433     8567.612163
# 1434     8681.735829
# 1435    10684.970399
# Length: 1436, dtype: float64
